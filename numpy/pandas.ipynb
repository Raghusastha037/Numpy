# %%
import pandas as pd

# %%
df = pd.read_csv('police.csv')
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# 1            40.0       White                        Speeding
# 2            33.0       White                        Speeding
# 3            19.0       White                Call for Service
# 4            21.0       White                        Speeding
# ...           ...         ...                             ...
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type   stop_outcome  \
# 0              Speeding             False         NaN       Citation
# 1              Speeding             False         NaN       Citation
# 2              Speeding             False         NaN       Citation
# 3                 Other             False         NaN  Arrest Driver
# 4              Speeding             False         NaN       Citation
# ...                 ...               ...         ...            ...
# 91736          Speeding             False         NaN        Warning
# 91737         Equipment             False         NaN        Warning
# 91738  Moving violation             False         NaN        Warning
# 91739          Speeding             False         NaN       Citation
# 91740          Speeding             False         NaN       Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 0           False      0-15 Min               False
# 1           False      0-15 Min               False
# 2           False      0-15 Min               False
# 3            True     16-30 Min               False
# 4           False      0-15 Min               False
# ...           ...           ...                 ...
# 91736       False      0-15 Min               False
# 91737       False      0-15 Min               False
# 91738       False      0-15 Min               False
# 91739       False      0-15 Min               False
# 91740       False      0-15 Min               False
#
# [91741 rows x 15 columns]

# %%
df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN       Citation       False      0-15 Min               False
# 1         NaN       Citation       False      0-15 Min               False
# 2         NaN       Citation       False      0-15 Min               False
# 3         NaN  Arrest Driver        True     16-30 Min               False
# 4         NaN       Citation       False      0-15 Min               False

# %%
pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\raghu\appdata\local\programs\python\python311\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\raghu\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raghu\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raghu\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raghu\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\raghu\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pd.options.display.max_rows=20
df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN       Citation       False      0-15 Min               False
# 1         NaN       Citation       False      0-15 Min               False
# 2         NaN       Citation       False      0-15 Min               False
# 3         NaN  Arrest Driver        True     16-30 Min               False
# 4         NaN       Citation       False      0-15 Min               False

# %%
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# 1            40.0       White                        Speeding
# 2            33.0       White                        Speeding
# 3            19.0       White                Call for Service
# 4            21.0       White                        Speeding
# ...           ...         ...                             ...
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type   stop_outcome  \
# 0              Speeding             False         NaN       Citation
# 1              Speeding             False         NaN       Citation
# 2              Speeding             False         NaN       Citation
# 3                 Other             False         NaN  Arrest Driver
# 4              Speeding             False         NaN       Citation
# ...                 ...               ...         ...            ...
# 91736          Speeding             False         NaN        Warning
# 91737         Equipment             False         NaN        Warning
# 91738  Moving violation             False         NaN        Warning
# 91739          Speeding             False         NaN       Citation
# 91740          Speeding             False         NaN       Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 0           False      0-15 Min               False
# 1           False      0-15 Min               False
# 2           False      0-15 Min               False
# 3            True     16-30 Min               False
# 4           False      0-15 Min               False
# ...           ...           ...                 ...
# 91736       False      0-15 Min               False
# 91737       False      0-15 Min               False
# 91738       False      0-15 Min               False
# 91739       False      0-15 Min               False
# 91740       False      0-15 Min               False
#
# [91741 rows x 15 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# 1            40.0       White                        Speeding
# 2            33.0       White                        Speeding
# 3            19.0       White                Call for Service
# 4            21.0       White                        Speeding
# ...           ...         ...                             ...
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type   stop_outcome  \
# 0              Speeding             False         NaN       Citation
# 1              Speeding             False         NaN       Citation
# 2              Speeding             False         NaN       Citation
# 3                 Other             False         NaN  Arrest Driver
# 4              Speeding             False         NaN       Citation
# ...                 ...               ...         ...            ...
# 91736          Speeding             False         NaN        Warning
# 91737         Equipment             False         NaN        Warning
# 91738  Moving violation             False         NaN        Warning
# 91739          Speeding             False         NaN       Citation
# 91740          Speeding             False         NaN       Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 0           False      0-15 Min               False
# 1           False      0-15 Min               False
# 2           False      0-15 Min               False
# 3            True     16-30 Min               False
# 4           False      0-15 Min               False
# ...           ...           ...                 ...
# 91736       False      0-15 Min               False
# 91737       False      0-15 Min               False
# 91738       False      0-15 Min               False
# 91739       False      0-15 Min               False
# 91740       False      0-15 Min               False
#
# [91741 rows x 15 columns]>

# %%
df.describe()
# Out:
#        county_name  driver_age_raw    driver_age
# count          0.0    86414.000000  86120.000000
# mean           NaN     1970.491228     34.011333
# std            NaN      110.914909     12.738564
# min            NaN        0.000000     15.000000
# 25%            NaN     1967.000000     23.000000
# 50%            NaN     1980.000000     31.000000
# 75%            NaN     1987.000000     43.000000
# max            NaN     8801.000000     99.000000

# %%
df.shape
# Out:
# (91741, 15)

# %%
df.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [stop_date, stop_time, county_name, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation, search_conducted, search_type, stop_outcome, is_arrested, stop_duration, drugs_related_stop]
# Index: []

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# 1            40.0       White                        Speeding
# 2            33.0       White                        Speeding
# 3            19.0       White                Call for Service
# 4            21.0       White                        Speeding
# ...           ...         ...                             ...
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type   stop_outcome  \
# 0              Speeding             False         NaN       Citation
# 1              Speeding             False         NaN       Citation
# 2              Speeding             False         NaN       Citation
# 3                 Other             False         NaN  Arrest Driver
# 4              Speeding             False         NaN       Citation
# ...                 ...               ...         ...            ...
# 91736          Speeding             False         NaN        Warning
# 91737         Equipment             False         NaN        Warning
# 91738  Moving violation             False         NaN        Warning
# 91739          Speeding             False         NaN       Citation
# 91740          Speeding             False         NaN       Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 0           False      0-15 Min               False
# 1           False      0-15 Min               False
# 2           False      0-15 Min               False
# 3            True     16-30 Min               False
# 4           False      0-15 Min               False
# ...           ...           ...                 ...
# 91736       False      0-15 Min               False
# 91737       False      0-15 Min               False
# 91738       False      0-15 Min               False
# 91739       False      0-15 Min               False
# 91740       False      0-15 Min               False
#
# [91262 rows x 15 columns]

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.0-cp311-cp311-win_amd64.whl.metadata (113 kB)
#      ---------------------------------------- 0.0/113.8 kB ? eta -:--:--
#      -------------- ------------------------ 41.0/113.8 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 113.8/113.8 kB 1.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\raghu\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\raghu\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raghu\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\raghu\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.6-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.1 MB 3.1 MB/s eta 0:00:03
#     --------------------------------------- 0.2/8.1 MB 3.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/8.1 MB 2.2 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/8.1 MB 3.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/8.1 MB 3.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/8.1 MB 3.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/8.1 MB 3.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/8.1 MB 3.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/8.1 MB 2.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.2/8.1 MB 2.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.1 MB 2.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.4/8.1 MB 2.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.4/8.1 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.1 MB 2.4 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.1 MB 2.5 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.1 MB 2.5 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.1 MB 2.5 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.1 MB 2.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.0/8.1 MB 2.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.0/8.1 MB 2.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.0/8.1 MB 2.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.3/8.1 MB 2.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.3/8.1 MB 2.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.1 MB/s eta 0:00:03
#    ------------ --------------------------- 2.5/8.1 MB 2.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.5/8.1 MB 2.2 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 2.4 MB/s eta 0:00:03
#    --------------- ------------------------ 3.2/8.1 MB 2.4 MB/s eta 0:00:03
#    --------------- ------------------------ 3.2/8.1 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.3/8.1 MB 2.3 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 2.5 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 2.5 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 2.6 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 4.3/8.1 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.6/8.1 MB 2.7 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.8 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.7 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.7 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 2.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 3.1 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.7/8.1 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.1 MB 3.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.1 MB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.1 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.7/8.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 3.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    --------------------------------------- 225.2/225.2 kB 14.3 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.0-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.3 MB ? eta -:--:--
#    ---------- ----------------------------- 0.6/2.3 MB 7.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.3 MB 7.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.7/2.3 MB 6.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.3 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 1.9/2.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.8 kB ? eta -:--:--
#    ---------------------------------------- 73.8/73.8 kB 2.1 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.7/7.0 MB 15.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/7.0 MB 13.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.9/7.0 MB 13.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.0/7.0 MB 16.0 MB/s eta 0:00:01
#    -------------------- ------------------- 3.6/7.0 MB 14.5 MB/s eta 0:00:01
#    ------------------------ --------------- 4.3/7.0 MB 15.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 15.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 15.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 15.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.7/7.0 MB 11.8 MB/s eta 0:00:01
#    -------------------------------- ------- 5.7/7.0 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- -- 6.5/7.0 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  6.8/7.0 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 8.3 MB/s eta 0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.9 kB ? eta -:--:--
#    ---------------------------------------  112.6/113.9 kB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 113.9/113.9 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.0 kiwisolver-1.4.9 matplotlib-3.10.6 pillow-11.3.0 pyparsing-3.2.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind='scatter',x='driver_age' , y='driver_age_raw',color = 'blue')
plt.xlabel('driver_age')
plt.ylabel('driver_age_raw')
plt.show()

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.corr()
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '2005-01-02'
